# %% [markdown]
# # Handling Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Sample Dataframe with outliers

# %%
data = {'values':[1,2,2,3,3,3,4,4,4,4,20]}
df = pd.DataFrame(data)

# %% [markdown]
# ### Create a box plot before removing outliers

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['values'])
plt.title("Box plot Before removing Outliers")
# Out:
# Text(0.5, 1.0, 'Box plot Before removing Outliers')

# %% [markdown]
# ## Identify outliers using the interquatile range (IQR)

# %%
Q1 = df['values'].quantile(0.25)
Q3 = df['values'].quantile(0.75)
IQR = Q3 - Q1

# %% [markdown]
# #### Define a Threshold to identify outliers

# %%
threshold = 1.5

# %% [markdown]
# ### Filter out outliers

# %%
filtered_data = df[(df['values'] >= Q1 - threshold * IQR) & (df['values'] <= Q3 + threshold * IQR)]

# %% [markdown]
# ## Create a box plot after removing outliers

# %%
plt.subplot(1, 2, 2)
sns.boxplot(x=filtered_data['values'])
plt.title('Box Plot After Removing Outliers')
# Out:
# Text(0.5, 1.0, 'Box Plot After Removing Outliers')

# %% [markdown]
# Display the plots

# %%
plt.tight_layout()
plt.show()
